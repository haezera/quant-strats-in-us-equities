# %%
import pandas as pd
from dotenv import load_dotenv
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import numpy as np
from sklearn.linear_model import Ridge
from scipy.stats.mstats import winsorize

class AlphaExtensionPortfolio:
    def __init__(
        self,
        db_url,
        table_mappings = {
            'prices': 'eom_prices',
            'factors': 'factor_scores',
            'constituents': 'monthly_constituents'
        },
        lookback_period=3,
        factors=['EVEBIT', 'EVEBITDA', 'MOMENTUM', 'PB', 'PE', 'PS'],
        winsorize_data=True,
        transaction_cost=0.05,
        trade_list_directory = './trade_lists'
    ):
        """
        Args:
            db_url: PostgreSQL database url for sqlalchemy
            table_mappings: Mappings for required data to your own database
            lookback_period: # of months to lookback for training
            factors: factors you wish to use in your factors database
            winsorize_data: should we winsorize the data in training
            transaction_cost: your transaction cost assumption
            trade_list: where to save the trade list worksheet
        """
        self.portfolio_settings = {
            'lookback_period': lookback_period,
            'factors': factors,
            'winsorize_data': winsorize_data,
            'transaction_cost': transaction_cost
        }
        self.alpha_model = None
        self.alpha_weights = None

    def backtest_on_period(
        start_date, end_date
    ):


    def train_on_period(
        start_date, end_date
    ):

    def trade_on_date(
        trade_date
    ):
        """
        Generates a trade list 
        """
